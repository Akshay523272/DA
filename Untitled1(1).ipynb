# %%
import pandas as pd
df=pd.read_csv("DataFrames_Dataset_4thQuestion - Copy.csv")
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      4/9/2012       58                 8                4
# ...

# %%
df.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      4/9/2012       58                 8                4
# 1        46344.0      8/3/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     10/2/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %%
df.tail()
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 494        55614.0    11/27/2013       85                 9                6
# 495        59432.0     4/13/2013       88                 5               11
# 496        55563.0      5/4/2014       22                 2                3
# 497        43624.0     4/21/2013       83                 4                4
# 498        41461.0     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms
# 494           0      3         11
# 495           0      3         11
# ...

# %%
df.shape
# Out:
# (499, 12)

# %%
df["marital_status"].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed',
#        'Widow'], dtype=object)

# %%
df["marital_status"].replace("widow","widowed")
# Out:
# 0            Single
# 1           Married
# 2          Divorced
# 3      Relationship
# 4           Widowed
#            ...
# 494        Divorced
# 495        Divorced
# 496        Divorced
# 497    Relationship
# 498    Relationship
# Name: marital_status, Length: 499, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# Length: 499, dtype: bool

# %%
df[["year_of_birth ",'educational_level', 'annual_income']]
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 494            1944               PhD        55614.0
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
#
# [499 rows x 3 columns]

# %%
df.loc[:6]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      4/9/2012       58                 8                4
# 1        46344.0      8/3/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     10/2/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
df.iloc[:7]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      4/9/2012       58                 8                4
# 1        46344.0      8/3/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     10/2/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
df.loc[df["educational_level"].isin(["Graduation","Master"])]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 5       20201706            1967            Master   Relationship
# ..           ...             ...               ...            ...
# 491     20202192            1976        Graduation       Divorced
# 492     20202193            1955        Graduation   Relationship
# 493     20202194            1964            Master         Single
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      4/9/2012       58                 8                4
# ...

# %%
df.loc[(df["educational_level"]=="Master")&(df["annual_income"]>75000)]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %%
df.loc[(df["educational_level"].isin(["Master"]))&(df["annual_income"]>75000)]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %%
df.set_index("customer_id")   #https://towardsdatascience.com/pandas-in-practice-64be9228062a
# Out:
#              year_of_birth  educational_level marital_status  annual_income  \
# customer_id
# 20201701               1982        Graduation         Single        58138.0
# 20201702               1950        Graduation        Married        46344.0
# 20201703               1965        Graduation       Divorced        71613.0
# 20201704               1984        Graduation   Relationship        26646.0
# 20201705               1981               PhD        Widowed        58293.0
# ...                     ...               ...            ...            ...
# 20202195               1944               PhD       Divorced        55614.0
# 20202196               1962            Master       Divorced        59432.0
# 20202197               1978        Graduation       Divorced        55563.0
# 20202198               1971               PhD   Relationship        43624.0
# 20202199               1949               PhD   Relationship        41461.0
#
# ...

# %%
df.sort_values(by=["year_of_birth "],ascending=True)
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 339     20202040            1899               PhD         Single
# 32      20201733            1940        Graduation        Married
# 358     20202059            1943            Master        Married
# 39      20201740            1943               PhD       Divorced
# 494     20202195            1944               PhD       Divorced
# ..           ...             ...               ...            ...
# 16      20201717            2000        Graduation        Married
# 418     20202119            2000        Graduation         Single
# 116     20201817            2000        Graduation   Relationship
# 185     20201886            2000        Graduation         Single
# 452     20202153            2000            Master         Single
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 339        83532.0     9/26/2013       36                 4                4
# ...

# %%
df['sum_purchases']=df.online_purchases+df.store_purchases
df['sum_purchases']
# Out:
# 0      12
# 1       3
# 2      18
# 3       6
# 4      11
#        ..
# 494    15
# 495    16
# 496     5
# 497     8
# 498    17
# Name: sum_purchases, Length: 499, dtype: int64

# %%
a=df.online_purchases+df.store_purchases
a
# Out:
# 0      12
# 1       3
# 2      18
# 3       6
# 4      11
#        ..
# 494    15
# 495    16
# 496     5
# 497     8
# 498    17
# Length: 499, dtype: int64

# %%
df['purhcase_date']=pd.to_datetime(df['purhcase_date'])
df['purhcase_date']
# Out:
# 0     2012-04-09
# 1     2014-08-03
# 2     2013-08-21
# 3     2014-10-02
# 4     2014-01-19
#          ...
# 494   2013-11-27
# 495   2013-04-13
# 496   2014-05-04
# 497   2013-04-21
# 498   2014-05-22
# Name: purhcase_date, Length: 499, dtype: datetime64[ns]

# %%
df['year_of_birth ']=df['year_of_birth '].astype(int)
df['year_of_birth ']
# Out:
# 0      1982
# 1      1950
# 2      1965
# 3      1984
# 4      1981
#        ...
# 494    1944
# 495    1962
# 496    1978
# 497    1971
# 498    1949
# Name: year_of_birth , Length: 499, dtype: int32

# %%
#x=df.year_of_birth  
#x
x=df['store_purchases']
type(x)
# Out:
# pandas.core.series.Series

# %%
type(df.customer_id)
# Out:
# pandas.core.series.Series

# %%
x=pd.to_datetime("now").year
x
# Out:
# C:\Users\exam2\AppData\Local\Temp\ipykernel_15604\519509904.py:1: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   x=pd.to_datetime("now").year
# 2023

# %%
#from pandas import date
#today = date.today()
#year = int(today.year)
#df['Age'] = year - df['year_of_birth ']
#df['Age']

# %%
df['Age'] = x - df['year_of_birth ']
df['Age']
# Out:
# 0      41
# 1      73
# 2      58
# 3      39
# 4      42
#        ..
# 494    79
# 495    61
# 496    45
# 497    52
# 498    74
# Name: Age, Length: 499, dtype: int32

# %%
df["week_date"] = [int(f'{i.isocalendar()[0]}{i.isocalendar()[1]}') for i in df.purhcase_date]
df["week_date"]
# Out:
# 0      201215
# 1      201431
# 2      201334
# 3      201440
# 4       20143
#         ...
# 494    201348
# 495    201315
# 496    201418
# 497    201316
# 498    201421
# Name: week_date, Length: 499, dtype: int64

# %%
for i in df.purhcase_date:
    print(i.isocalendar()[0],i.isocalendar()[1])
# Out:
# 2012 15
# 2014 31
# 2013 34
# 2014 40
# 2014 3
# 2013 37
# 2012 46
# 2013 32
# 2013 23
# 2014 11
# 2013 46
# 2012 46
# 2013 46
# 2013 46
# 2012 41
# 2012 47
# 2012 52
# 2012 35
# 2013 13
# 2012 10
# 2012 32
# 2013 22
# 2012 51
# 2014 44
# 2013 12
# 2013 5
# 2013 22
# 2013 8
# 2013 22
# 2013 47
# 2014 21
# 2013 45
# 2012 41
# 2012 44
# 2013 8
# 2013 35
# 2014 1
# 2013 6
# 2014 44
# 2013 1
# 2013 18
# 2013 49
# 2012 52
# 2013 19
# 2013 6
# 2014 26
# 2012 37
# 2013 21
# 2014 1
# 2012 32
# 2014 49
# 2012 45
# 2013 5
# 2014 27
# 2013 49
# 2012 47
# 2013 6
# 2014 18
# 2013 25
# 2014 10
# 2013 14
# 2012 28
# 2013 8
# 2013 45
# 2013 24
# 2013 21
# 2014 45
# 2014 12
# 2013 39
# 2013 31
# 2012 45
# 2012 37
# 2013 11
# 2013 18
# 2014 18
# 2012 51
# 2012 35
# 2012 50
# 2013 15
# 2013 5
# 2012 35
# 2013 25
# 2013 10
# 2013 45
# 2014 9
# 2013 45
# 2013 29
# 2014 22
# 2014 49
# 2014 4
# 2012 47
# 2014 22
# 2013 47
# 2014 12
# 2014 21
# 2014 21
# 2012 47
# 2013 45
# 2013 2
# 2013 25
# 2013 30
# ...

# %%
agg=df.groupby(by="educational_level")['annual_income', 'recency', 'store_purchases',  'online_purchases'].mean().reset_index()
agg
# Out:
# C:\Users\exam2\AppData\Local\Temp\ipykernel_15604\1646908671.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   agg=df.groupby(by="educational_level")['annual_income', 'recency', 'store_purchases',  'online_purchases'].mean().reset_index()
#   educational_level  annual_income    recency  store_purchases  \
# 0             Basic   19514.571429  53.571429         2.857143
# 1        Graduation   51607.827309  47.171206         5.840467
# 2       High School   44154.717949  58.400000         4.600000
# 3            Master   51191.700000  45.000000         5.691358
# 4               PhD   55878.990991  49.008772         6.298246
#
#    online_purchases
# 0          1.571429
# 1          3.887160
# 2          3.450000
# 3          4.049383
# 4          4.429825

# %%
import numpy as np
pivot_table = pd.DataFrame(pd.pivot_table(df, values=['sum_purchases', 'recency'],
                                              index=['marital_status'],
                                               columns=['educational_level'],
                                              aggfunc={'recency': np.mean, 'sum_purchases': np.sum},
                                                  fill_value=0)).reset_index()
pivot_table
# Out:
#                   marital_status    recency                                    \
# educational_level                     Basic Graduation High School     Master
# 0                       Divorced  68.333333  54.897959   64.666667  60.083333
# 1                        Married   0.000000  42.701493   66.866667  50.315789
# 2                   Relationship  39.333333  48.196078   49.615385  36.800000
# 3                         Single  52.000000  44.278689   49.000000  42.761905
# 4                          Widow   0.000000  61.000000   96.000000  14.000000
# 5                        Widowed   0.000000  46.760000   52.000000  40.000000
#
#                              sum_purchases
# educational_level        PhD         Basic Graduation High School Master  PhD
# 0                  41.350000            13        481          31    134  232
# 1                  60.000000             0        652         120    193  236
# ...

# %%
import pandas as pd
df=pd.read_csv("pizza_price_prediction_5thquestion.csv")
df
# Out:
#     company price_cad  diameter      topping           variant     size  \
# 0         A      $29    22 inch      chicken  double_signature    jumbo
# 1         A      $25    20 inch    papperoni  double_signature    jumbo
# 2         A      $19    16 inch    mushrooms  double_signature  reguler
# 3         A      $22    14 inch  smoked_beef  double_signature  reguler
# 4         A      $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...       ...       ...          ...               ...      ...
# 124       E      $11   8.5 inch         tuna        spicy tuna    small
# 125       E      $14    12 inch         tuna        spicy tuna   medium
# 126       E      $17    14 inch         tuna        spicy tuna    large
# 127       E      $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E      $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms
# 0           yes          yes              no
# ...
