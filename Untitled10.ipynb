# %%
import pandas as pd
df=pd.read_csv("Z:\pizza_price_prediction_5thquestion.csv")
df
# Out:
#     company price_cad  diameter      topping           variant     size  \
# 0         A      $29    22 inch      chicken  double_signature    jumbo
# 1         A      $25    20 inch    papperoni  double_signature    jumbo
# 2         A      $19    16 inch    mushrooms  double_signature  reguler
# 3         A      $22    14 inch  smoked_beef  double_signature  reguler
# 4         A      $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...       ...       ...          ...               ...      ...
# 124       E      $11   8.5 inch         tuna        spicy tuna    small
# 125       E      $14    12 inch         tuna        spicy tuna   medium
# 126       E      $17    14 inch         tuna        spicy tuna    large
# 127       E      $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E      $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms
# 0           yes          yes              no
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
i=[0,1,2,3,4]
print(i[1:])
# Out:
# [1, 2, 3, 4]

# %%
df['price_card'] = [int(i[1:]) for i in df['price_cad']]
df.groupby('company')['price_card'].mean()
# Out:
# company
# A    19.600
# B    14.375
# C    13.800
# D    16.600
# E    14.400
# Name: price_card, dtype: float64

# %%
df.iloc[[0]]
# Out:
#   company price_cad diameter  topping           variant   size extra_sauce  \
# 0       A      $29   22 inch  chicken  double_signature  jumbo         yes
#
#   extra_cheese extra_mushrooms  price_card
# 0          yes              no          29

# %%
df.groupby(["diameter","company"]).filter(lambda x:x['variant'].nunique()>1)["company"].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E'], dtype=object)

# %%
import matplotlib.pyplot as plt

pi= df["company"].value_counts()
pi
x=plt.bar(pi,x="ee",y="r")
x.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 5
#       3 pi= df["company"].value_counts()
#       4 pi
# ----> 5 x=plt.bar(pi,x="ee",y="r")
#       6 x.show()
#
# TypeError: bar() got multiple values for argument 'x'

# %%
print("Total no.of null values: ", df.isnull().sum().sum())
# Out:
# Total no.of null values:  0

# %%
df.rename(columns={'price_cad':'price'})
# Out:
#     company price  diameter      topping           variant     size  \
# 0         A  $29    22 inch      chicken  double_signature    jumbo
# 1         A  $25    20 inch    papperoni  double_signature    jumbo
# 2         A  $19    16 inch    mushrooms  double_signature  reguler
# 3         A  $22    14 inch  smoked_beef  double_signature  reguler
# 4         A  $30    18 inch   mozzarella  double_signature    jumbo
# ..      ...   ...       ...          ...               ...      ...
# 124       E  $11   8.5 inch         tuna        spicy tuna    small
# 125       E  $14    12 inch         tuna        spicy tuna   medium
# 126       E  $17    14 inch         tuna        spicy tuna    large
# 127       E  $12   8.5 inch         meat   BBQ_meat_fiesta    small
# 128       E  $15    12 inch         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms  price_card
# 0           yes          yes              no          29
# ...

# %%
df.groupby('variant')['company'].nunique()
# Out:
# variant
# BBQ_meat_fiesta      2
# BBQ_sausage          1
# american_classic     1
# american_favorite    1
# classic              3
# crunchy              3
# double_decker        3
# double_mix           2
# double_signature     1
# extravaganza         1
# gournet_greek        1
# italian_veggie       1
# meat_eater           1
# meat_lovers          2
# neptune_tuna         1
# new_york             3
# spicy tuna           1
# spicy_tuna           1
# super_supreme        1
# thai_veggie          1
# Name: company, dtype: int64

# %%
x=max(df['price_card'])
df[df['price_card']==x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 30
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 30
#
# The above exception was the direct cause of the following exception:
#
# ...
