# %%
import numpy as np
import pandas as pd
df=pd.read_csv("D:\iris.txt",names=[0,1,2,3,4])
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print("shape is:",df.shape)
print("dimn is:",df.ndim)
print("size is:",df.size)
# Out:
# shape is: (150, 5)
# dimn is: 2
# size is: 750

# %%
ir1,ir2,ir3=np.split(df,3)
print("iris1 is:\n",ir1)
print("iris2 is:\n",ir2)
print("iris3 is:\n",ir3)
# Out:
# iris1 is:
#        0    1    2    3            4
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# ...

# %%
header=["sepal length","sepal width","petal length","petal width","Species No"]
header
# Out:
# ['sepal length', 'sepal width', 'petal length', 'petal width', 'Species No']

# %%
iris_max=np.max(df,axis=0)
print("max of columns:\n",iris_max)
# Out:
# max of columns:
#  0               7.9
# 1               4.4
# 2               6.9
# 3               2.5
# 4    Iris-virginica
# dtype: object

# %%
iris_min=np.min(df,axis=0)
print("min of columns:\n",iris_min)
# Out:
# min of columns:
#  0            4.3
# 1            2.0
# 2            1.0
# 3            0.1
# 4    Iris-setosa
# dtype: object

# %%
iris_mean=np.mean(df,axis=0)
print("mean of columns:\n",iris_mean)
print(np.round(iris_mean,2))
# Out:
# mean of columns:
#  0    5.843333
# 1    3.054000
# 2    3.758667
# 3    1.198667
# dtype: float64
# 0    5.84
# 1    3.05
# 2    3.76
# 3    1.20
# dtype: float64
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
iris_std=np.std(df,axis=0)
print("standard deviation  of columns:\n",iris_std)
print(np.round(iris_std,2))
# Out:
# standard deviation  of columns:
#  0    0.825301
# 1    0.432147
# 2    1.758529
# 3    0.760613
# dtype: float64
# 0    0.83
# 1    0.43
# 2    1.76
# 3    0.76
# dtype: float64
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3603: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
iris_var=np.var(df,axis=0)
print("variance  of columns:\n",iris_var)
print(np.round(iris_var,2))
# Out:
# variance  of columns:
#  0    0.681122
# 1    0.186751
# 2    3.092425
# 3    0.578532
# dtype: float64
# 0    0.68
# 1    0.19
# 2    3.09
# 3    0.58
# dtype: float64
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3745: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
iris_max=np.max(ir1,axis=0)
print("max of columns:\n",iris_max)
iris_min=np.min(ir1,axis=0)
print("min of columns:\n",iris_min)
iris_mean=np.mean(ir1,axis=0)
print("mean of columns:\n",iris_mean)
print(np.round(iris_mean,2))
iris_std=np.std(ir1,axis=0)
print("standard deviation  of columns:\n",iris_std)
print(np.round(iris_std,2))
iris_var=np.var(ir1,axis=0)
print("variance  of columns:\n",iris_var)
print(np.round(iris_var,2))
# Out:
# max of columns:
#  0            5.8
# 1            4.4
# 2            1.9
# 3            0.6
# 4    Iris-setosa
# dtype: object
# min of columns:
#  0            4.3
# 1            2.3
# 2            1.0
# 3            0.1
# 4    Iris-setosa
# dtype: object
# mean of columns:
#  0    5.006
# 1    3.418
# 2    1.464
# 3    0.244
# dtype: float64
# 0    5.01
# 1    3.42
# 2    1.46
# 3    0.24
# dtype: float64
# standard deviation  of columns:
#  0    0.348947
# 1    0.377195
# 2    0.171767
# 3    0.106132
# dtype: float64
# 0    0.35
# 1    0.38
# 2    0.17
# 3    0.11
# dtype: float64
# variance  of columns:
#  0    0.121764
# 1    0.142276
# 2    0.029504
# 3    0.011264
# dtype: float64
# 0    0.12
# 1    0.14
# 2    0.03
# 3    0.01
# dtype: float64
# ...

# %%
iris_max=np.max(ir2,axis=0)
print("max of columns:\n",iris_max)
iris_min=np.min(ir2,axis=0)
print("min of columns:\n",iris_min)
iris_mean=np.mean(ir2,axis=0)
print("mean of columns:\n",iris_mean)
print(np.round(iris_mean,2))
iris_std=np.std(ir2,axis=0)
print("standard deviation  of columns:\n",iris_std)
print(np.round(iris_std,2))
iris_var=np.var(ir2,axis=0)
print("variance  of columns:\n",iris_var)
print(np.round(iris_var,2))
# Out:
# max of columns:
#  0                7.0
# 1                3.4
# 2                5.1
# 3                1.8
# 4    Iris-versicolor
# dtype: object
# min of columns:
#  0                4.9
# 1                2.0
# 2                3.0
# 3                1.0
# 4    Iris-versicolor
# dtype: object
# mean of columns:
#  0    5.936
# 1    2.770
# 2    4.260
# 3    1.326
# dtype: float64
# 0    5.94
# 1    2.77
# 2    4.26
# 3    1.33
# dtype: float64
# standard deviation  of columns:
#  0    0.510983
# 1    0.310644
# 2    0.465188
# 3    0.195765
# dtype: float64
# 0    0.51
# 1    0.31
# 2    0.47
# 3    0.20
# dtype: float64
# variance  of columns:
#  0    0.261104
# 1    0.096500
# 2    0.216400
# 3    0.038324
# dtype: float64
# 0    0.26
# 1    0.10
# 2    0.22
# 3    0.04
# dtype: float64
# ...

# %%
iris_max=np.max(ir3,axis=0)
print("max of columns:\n",iris_max)
iris_min=np.min(ir3,axis=0)
print("min of columns:\n",iris_min)
iris_mean=np.mean(ir3,axis=0)
print("mean of columns:\n",iris_mean)
print(np.round(iris_mean,2))
iris_std=np.std(ir3,axis=0)
print("standard deviation  of columns:\n",iris_std)
print(np.round(iris_std,2))
iris_var=np.var(ir3,axis=0)
print("variance  of columns:\n",iris_var)
print(np.round(iris_var,2))
# Out:
# max of columns:
#  0               7.9
# 1               3.8
# 2               6.9
# 3               2.5
# 4    Iris-virginica
# dtype: object
# min of columns:
#  0               4.9
# 1               2.2
# 2               4.5
# 3               1.4
# 4    Iris-virginica
# dtype: object
# mean of columns:
#  0    6.588
# 1    2.974
# 2    5.552
# 3    2.026
# dtype: float64
# 0    6.59
# 1    2.97
# 2    5.55
# 3    2.03
# dtype: float64
# standard deviation  of columns:
#  0    0.629489
# 1    0.319255
# 2    0.546348
# 3    0.271890
# dtype: float64
# 0    0.63
# 1    0.32
# 2    0.55
# 3    0.27
# dtype: float64
# variance  of columns:
#  0    0.396256
# 1    0.101924
# 2    0.298496
# 3    0.073924
# dtype: float64
# 0    0.40
# 1    0.10
# 2    0.30
# 3    0.07
# dtype: float64
# ...
